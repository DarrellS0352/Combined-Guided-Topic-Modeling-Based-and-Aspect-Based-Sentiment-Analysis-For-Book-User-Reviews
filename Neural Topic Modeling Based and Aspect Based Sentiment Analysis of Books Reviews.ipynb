# %% [markdown]
# # Import libraries

# %%
import pandas as pd
import numpy as np

import unidecode
from bs4 import BeautifulSoup
import re
import contractions
import spacy

from keybert import KeyBERT
from keyphrase_vectorizers import KeyphraseCountVectorizer
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
from sentence_transformers import SentenceTransformer
from transformers import pipeline

import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.cm import ScalarMappable
# %matplotlib inline

import gc
gc.enable()

import warnings
warnings.filterwarnings("ignore")
pd.set_option('max_columns',None)

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))

# For dark mode
from jupyterthemes import jtplot
jtplot.style(theme='onedork', context='notebook', ticks=True, grid=True)
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # Import data
# Original data is much larger but for development and presentation reasons I am using only one book. When productionized, this process will be siloed for individual books anyway.

# %%
# Set input filepath
input_filepath = './input/'
filename = 'one_book.pkl'

df = pd.read_pickle(input_filepath + filename)
print(df.shape)
df.head()
# Out:
# (1540, 8)
#           user_id     book_id  rating  \
# 0   AF7X31XYRC21M  0316129089     5.0
# 1  A1OL3QQXYHQEII  0316129089     5.0
# 2   AHUGIW3I35770  0316129089     4.0
# 3  A14BAROCIAMNRK  0316129089     5.0
# 4  A3060WHB3J9OCM  0316129089     4.0
#
#                                              summary  \
# 0               Recommend 100% to all sci-fi readers
# 1                                          Good Book
# 2                                     Good Sci-fi...
# 3  Exciting,well written, and plausible science f...
# 4                                    Good space book
#
#                                          review_text       date  \
# 0  Have read all 6 books after viewing the first ... 2018-04-19
# 1  One of the best sci-fi books around.  Good plo... 2018-04-18
# 2  Is a human story with a sci-fi twist, as it sl... 2018-04-17
# 3  It isn't often that a television show gets me ... 2018-04-17
# 4  Feels like the author really wanted to combine... 2018-04-16
#
#              title                   category
# 0  leviathan wakes  science fiction & fantasy
# 1  leviathan wakes  science fiction & fantasy
# 2  leviathan wakes  science fiction & fantasy
# 3  leviathan wakes  science fiction & fantasy
# 4  leviathan wakes  science fiction & fantasy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1540 entries, 0 to 1539
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   user_id      1540 non-null   object
#  1   book_id      1540 non-null   object
#  2   rating       1540 non-null   float64
#  3   summary      1540 non-null   object
#  4   review_text  1539 non-null   object
#  5   date         1540 non-null   datetime64[ns]
#  6   title        1540 non-null   object
#  7   category     1540 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 96.4+ KB

# %%
df.isnull().sum()
# Out:
# user_id        0
# book_id        0
# rating         0
# summary        0
# review_text    1
# date           0
# title          0
# category       0
# dtype: int64

# %%
df.dropna(subset=['review_text'], inplace=True)

# %% [markdown]
# # Data Pre-processing
# + remove urls
# + unicode normalization
# + remove html
# + remove emojis
# + lowercase
# + expand contractions
# + remove whitespace

# %% [markdown]
# #### Text cleaning functions

# %%
# unicode normalization
def clean_unicode(text):
    text = unidecode.unidecode(text)
    return text

# remove html
def remove_html(text):
    text = BeautifulSoup(text, "html.parser")
    return text.get_text()

# remove URLs
def remove_url(text):
    text = re.sub(r'http\S+', '', text)
    return text

# normalize contractions
def expand_contractions(text):
    text = contractions.fix(text)
    return text

# emojis
def remove_emojis(text):
    emoji_pattern = re.compile("["
            u"\U0001F600-\U0001F64F"  # emoticons
            u"\U0001F300-\U0001F5FF"  # symbols & pictographs
            u"\U0001F680-\U0001F6FF"  # transport & map symbols
            u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               "]+", flags=re.UNICODE)
    
    text = emoji_pattern.sub(r'', text)
    return text

# remove whitspace
def remove_whitespace(text):
    # remove whitespace at beginning and end of string
    text = re.sub("^\s+|\s+$", "", text, flags=re.UNICODE)
    # remove duplicate spaces
    text = " ".join(re.split("\s+", text, flags=re.UNICODE))
    # whitespace around punctuation
    text = re.sub(r'\s(?=[\.,:;])', "", text)
    return text

# convert back to string
def tokens_to_string(tokens):
    text = " ".join(tokens)
    return text

# %% [markdown]
# #### Clean reviews

# %%
# %%time

nlp = spacy.load('en_core_web_lg')

reviews = df.review_text.tolist()

cleaned_sentences = []
original_review = []
for review in reviews:
    doc = nlp(review) # spacy object
    for sent in doc.sents:
        text = sent.text
        text = clean_unicode(text) # remove unicode
        text = remove_html(text) # remove html
        text = remove_url(text) # remove url
        text = remove_emojis(text) # remove emojis
        text = expand_contractions(text) # expand contractions
        text = remove_whitespace(text) # remove extra whitespace
        text = text.lower() # lowercase
        cleaned_sentences.append(text)
        original_review.append(doc.text)
        
# add to DF
df_ = pd.DataFrame({'review_text':original_review, 'cleaned_sentence':cleaned_sentences})
df3 = df_.merge(df, how='left', on='review_text')
df3
# Out:
# Wall time: 22.5 s
#                                             review_text  \
# 0     Have read all 6 books after viewing the first ...
# 1     Have read all 6 books after viewing the first ...
# 2     Have read all 6 books after viewing the first ...
# 3     One of the best sci-fi books around.  Good plo...
# 4     One of the best sci-fi books around.  Good plo...
# ...                                                 ...
# 6897  I don't usually write reviews.  This book dese...
# 6898  Was happy to find out there was a book series ...
# 6899  Was happy to find out there was a book series ...
# 6900  Was happy to find out there was a book series ...
# 6901  Was happy to find out there was a book series ...
#
#                                        cleaned_sentence         user_id  \
# 0     have read all 6 books after viewing the first ...   AF7X31XYRC21M
# 1     they were excellent for filling in the backgro...   AF7X31XYRC21M
# 2     can wholeheartedly recommend them to all sci-f...   AF7X31XYRC21M
# 3                  one of the best sci-fi books around.  A1OL3QQXYHQEII
# 4     good plot and believable tech makes this a gre...  A1OL3QQXYHQEII
# ...                                                 ...             ...
# 6897  he would be ejecting rounds unless the gun was...  A1AJDC30B7FKVB
# 6898  was happy to find out there was a book series ...  A3QATDHUASPFUU
# 6899                 read this book in just a few days.  A3QATDHUASPFUU
# 6900  was very impressed with how faithful the tv se...  A3QATDHUASPFUU
# 6901                                    on to book two!  A3QATDHUASPFUU
#
#          book_id  rating                                            summary  \
# 0     0316129089     5.0               Recommend 100% to all sci-fi readers
# 1     0316129089     5.0               Recommend 100% to all sci-fi readers
# 2     0316129089     5.0               Recommend 100% to all sci-fi readers
# 3     0316129089     5.0                                          Good Book
# 4     0316129089     5.0                                          Good Book
# ...          ...     ...                                                ...
# 6897  0316129089     5.0  Great detective story, set in the future and i...
# 6898  0316129089     5.0                                  Excellent Pairing
# 6899  0316129089     5.0                                  Excellent Pairing
# 6900  0316129089     5.0                                  Excellent Pairing
# 6901  0316129089     5.0                                  Excellent Pairing
#
#            date            title                   category
# 0    2018-04-19  leviathan wakes  science fiction & fantasy
# 1    2018-04-19  leviathan wakes  science fiction & fantasy
# 2    2018-04-19  leviathan wakes  science fiction & fantasy
# 3    2018-04-18  leviathan wakes  science fiction & fantasy
# 4    2018-04-18  leviathan wakes  science fiction & fantasy
# ...         ...              ...                        ...
# 6897 2018-04-24  leviathan wakes  science fiction & fantasy
# 6898 2018-04-23  leviathan wakes  science fiction & fantasy
# 6899 2018-04-23  leviathan wakes  science fiction & fantasy
# 6900 2018-04-23  leviathan wakes  science fiction & fantasy
# 6901 2018-04-23  leviathan wakes  science fiction & fantasy
#
# [6902 rows x 9 columns]

# %% [markdown]
# # Aspect extraction
# + KeyBERT utilizes BERT embeddings to produce keywords/phrases that best represent a document
# + KeyphraseVectorizer is an enhanced version of the CountVectorizer which is designed to find key phrases using part-of-speech patterns

# %% [markdown]
# #### Load key phrase extraction model

# %%
docs = df3.cleaned_sentence.tolist()
# pretrained model good for keyword/keyphrase extraction
kw_model = KeyBERT(model='distilbert-base-nli-mean-tokens')

# %% [markdown]
# #### Seed keywords
# This list of words will be used to nudge the model to focus on these words if possible. These words are various aspects of writing and books in general which are content-agnostic metrics that can be used for all books.

# %%
## elements of writing (ideal topics) to nudge model towards (if possible)
seed_keywords = [
    'setting',
    'character',
    'plot',
    'conflict',
    'theme',
    'point of view',
    'tone',
    'style',
    'dialogue',
    'action',
    'description',
    'exposition',
    'motivation',
    'symbolism',
    'climax',
    'resolution',
    'imagery',
    'pacing',
    'writing',
    'author',
]

# %% [markdown]
# #### Extract key phrases based on part-of-speech patterns

# %%
# %%time

# POS pattern ideas (Banjar et al., 2020)
pos_patterns = [
    '<JJ.*><NN.*>+', # adjective > noun(s)
    '<RB.*><RB.*><NN.*>+', # adverb > adverb > noun(s)
    '<RB.*><JJ.*><NN.*>+', # adverb > adjective > noun(s)
    '<RB.*><VB.*><NN.*>+', # adverb > verb > noun(s)
    '<VB.*><NN.*>+', # verb > noun(s)
]

column_names = [
    'jj_nn',
    'rb_rb_nn',
    'rb_jj_nn',
    'rb_vb_nn',
    'vb_nn',
]

keyword_dict = {}
column_name_counter = 0
# run a key phrase extraction for each pos pattern
for pos_pattern in pos_patterns:
    vectorizer = KeyphraseCountVectorizer(
        pos_pattern=pos_pattern,
        stop_words='english'
    )
    keywords = kw_model.extract_keywords(
        docs, 
        vectorizer=vectorizer,
        use_mmr=True, # diversify results
        diversity=0.7, # diversify results
        seed_keywords=seed_keywords
    )
    # add to dict
    keyword_dict[column_names[column_name_counter]] = keywords
    # iterating through col names
    column_name_counter += 1
# Out:
# Wall time: 6min 12s

# %% [markdown]
# #### Wrangle key phrases
# It is key to keep the length of all sublists equal

# %%
keyword_dict2 = {}
for key in keyword_dict.keys():
    pos_pattern_col = []
    for sublist in keyword_dict[key]:
        if sublist != []:
            pos_pattern_col.append([tup[0] for tup in sublist])
        else:
            pos_pattern_col.append(np.nan)
    keyword_dict2[key] = pos_pattern_col
keyword_dict2
# Out:
# {'jj_nn': [['first season'],
#   nan,
#   nan,
#   ['best sci fi books', 'best sci fi', 'best sci'],
#   ['gritty novel', 'good plot', 'believable tech'],
#   ['fantastic climax', 'human story'],
#   ['future society', 'modern society'],
#   ['political world'],
#   ['plausible science fiction',
#    'excellent prose',
#    'first rate story telling',
#    'realistic politics',
#    'first rate'],
#   nan,
#   ['popular fiction', 'great book', 'intriguing world'],
#   nan,
#   ['audible book version'],
#   ['decent job'],
#   ['male characters', 'sexual interest', 'female characters'],
#   ['awesome book'],
#   ['top notch'],
#   nan,
#   ['proper science', 'light travel', 'artificial gravity'],
#   nan,
#   ['third book'],
#   ['fantastic tale'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['excellent novel'],
#   nan,
#   ['economic aspects'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['good choice'],
#   ['next book'],
#   nan,
#   ['cliched characters'],
#   ['scientific terminology', 'new information'],
#   nan,
#   ['chaotic mix', 'unreasonable events'],
#   ['unoriginal attempt'],
#   nan,
#   ['real scifi'],
#   nan,
#   nan,
#   ['best science fiction book', 'best science fiction'],
#   nan,
#   nan,
#   ['sustained suspense', 'great writing', 'own oxygen supply'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['best books', 'few years'],
#   ['civilian spaceship'],
#   ['different characters', 'linked events'],
#   nan,
#   nan,
#   ['exciting pick', 'slow start'],
#   ['futuristic read'],
#   ['future world', 'unique idea'],
#   ['good book'],
#   nan,
#   nan,
#   ['good noir novel', 'favorite genre'],
#   ['big turn'],
#   nan,
#   ['new adventure', 'new ports', 'solar system'],
#   ['idealistic ships officer', 'great characters', 'interwoven tale'],
#   nan,
#   ['long series'],
#   nan,
#   ['third read'],
#   ['first time'],
#   ['second time', 'deeper understanding'],
#   ['third time'],
#   ['real science'],
#   ['flawed details', 'massive level', 'human interaction'],
#   nan,
#   ['great space sci'],
#   nan,
#   nan,
#   nan,
#   ['syfy channel', 'same time promos', 'same time'],
#   ['captivating plot', 'main character'],
#   nan,
#   ['solar system', 'dystopian view'],
#   ['military superpowers', 'fragile coexistence'],
#   ['outer planets', 'physical differences'],
#   ['inner planets'],
#   nan,
#   ['real gripe'],
#   ['anachronistic stereotype', 'main characters'],
#   ['comic book detective', '24th century'],
#   nan,
#   nan,
#   ['catastrophic conspiracy', 'main character'],
#   ['broken everyman'],
#   nan,
#   nan,
#   nan,
#   ['first installment'],
#   ['short stories'],
#   nan,
#   nan,
#   ['complex characters'],
#   nan,
#   nan,
#   ['good sci fi', 'good sci'],
#   ['best sci fi series', 'best sci fi', 'best sci'],
#   nan,
#   ['favorite part'],
#   nan,
#   ['many moments'],
#   nan,
#   ['great scifi book', 'great scifi'],
#   ['hard scifi', 'good mix'],
#   nan,
#   nan,
#   ['big gulps', 'first installment'],
#   ['shorter sips'],
#   nan,
#   nan,
#   nan,
#   ['egregious case', 'good adventure'],
#   ['amazing space opera', 'more insight'],
#   nan,
#   ['good series', 'first episode', 'good job'],
#   ['fun read'],
#   ['next book'],
#   ['good science fiction', 'more authors', 'good science', 'military yarns'],
#   ['great book'],
#   nan,
#   nan,
#   ['hard scifi'],
#   ['first novel', 'leviathan wakes', 'great job', 'near future'],
#   ['scientific realism'],
#   nan,
#   nan,
#   nan,
#   ['best attributes'],
#   nan,
#   nan,
#   ['good ideas'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['immense story arc', 'satisfying read', 'unique universe'],
#   ['deep character development', 'fantastic humor', 'new level'],
#   nan,
#   ['syfy channel'],
#   nan,
#   ['syfy book'],
#   nan,
#   ['real feel'],
#   ['bloated books', 'syfy authors'],
#   nan,
#   ['avid syfy reader'],
#   ['first book'],
#   ['solar system'],
#   ['witty sentences'],
#   ['epic storytelling', 'gritty believability'],
#   nan,
#   nan,
#   ['future sci', 'near future'],
#   ['new layers'],
#   nan,
#   ['first season'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['different characters'],
#   ['great contrasts', 'unforgiving universe', 'main characters'],
#   nan,
#   ['many parts'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['double vision'],
#   nan,
#   nan,
#   ['dynamic geopolitics', 'convincing imagining', 'real characters'],
#   ['favorite scifi'],
#   ['great scifi tales',
#    'scifi tropes',
#    'great scifi',
#    'hard scifi',
#    'own identity'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['other stories'],
#   nan,
#   ['great read'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['great anticipation'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['nefarious corporations',
#    'political intrigue',
#    'local walmart',
#    'top drama',
#    'diverse factions'],
#   nan,
#   ['accurate portrayal', 'human race'],
#   nan,
#   nan,
#   nan,
#   ['solid story line',
#    'solid story',
#    'dimensional characters',
#    'ethical issues'],
#   nan,
#   ['detective story', 'good mix'],
#   nan,
#   ['new author'],
#   ['gripping story'],
#   ['second book'],
#   nan,
#   ['caliban war'],
#   nan,
#   ['great space opera'],
#   ['good book'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['artificial gravity', 'basic science'],
#   nan,
#   nan,
#   nan,
#   ['great science fiction book', 'great science fiction', 'technical over'],
#   ['fresh storyline', 'good character development', 'good character'],
#   nan,
#   ['better detail'],
#   nan,
#   ['great book', 'great read', 'great series', 'instant classic'],
#   nan,
#   nan,
#   nan,
#   ['first book'],
#   ['better appreciation'],
#   ['actual science'],
#   ['compelling characters'],
#   ['solar system politics', 'solar system', 'personal tragedies'],
#   ['great read'],
#   ['light years'],
#   nan,
#   ['many seasons', 'whole story'],
#   nan,
#   ['nice change', 'true banks'],
#   ['solar system', 'good character'],
#   ['technical challenges', 'sound manner'],
#   ['great story', 'great concept'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['constant themes', 'individual decisions'],
#   nan,
#   nan,
#   nan,
#   ['massive world building',
#    'solar system',
#    'delicate economy',
#    'dimensional nature'],
#   ['heavy focus'],
#   ['detective noir type story',
#    'detective noir',
#    'techy romp',
#    'nice substance balance'],
#   nan,
#   nan,
#   ['political intrigue'],
#   nan,
#   ['favorite series'],
#   ['strong start'],
#   ['possible future'],
#   ['huge tensions', 'solar system'],
#   ['social issues'],
#   ['plausible world'],
#   ['hard sci fi', 'hard sci'],
#   nan,
#   ['scientific discovery',
#    'large conspiracy',
#    'first novel',
#    'detective story'],
#   ['other star systems', 'hard sci fi', 'interstellar travel', 'hard sci'],
#   ['larger story arch progresses', 'several books', 'larger story'],
#   nan,
#   ['historical fiction', 'significant events'],
#   ['compelling storytelling', 'fascinating characters', 'social science'],
#   nan,
#   nan,
#   nan,
#   ['good book'],
#   ['best science fiction writer', 'best science fiction'],
#   ['great characters', 'great story'],
#   ['solar system', 'scientific leap', 'galactic struggles', 'light travel'],
#   nan,
#   nan,
#   ['great writing'],
#   ['great dialogue'],
#   nan,
#   ['main characters'],
#   nan,
#   nan,
#   ['good writing'],
#   nan,
#   ['holy moly'],
#   nan,
#   nan,
#   ['hard time', 'next chapter'],
#   nan,
#   ['whole series'],
#   ['few chapters'],
#   nan,
#   ['big sci fi geek', 'big sci', 'whole series'],
#   ['great job'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['great book'],
#   ['big sci'],
#   ['entire series'],
#   ['best sci fi books', 'best sci fi', 'best sci'],
#   ['strong plot', 'strong plot line', 'solid character development'],
#   nan,
#   ['beautiful world'],
#   ['next book'],
#   nan,
#   nan,
#   ['naval officer'],
#   nan,
#   nan,
#   ['more prostitute visuals'],
#   ['awesome book'],
#   nan,
#   ['top prize'],
#   nan,
#   nan,
#   nan,
#   ['unusual tale'],
#   ['leviathan wakes'],
#   nan,
#   nan,
#   ['decent characters', 'last half', 'great concept'],
#   ['more melodrama'],
#   ['more heat', 'more introspection', 'functional nature'],
#   nan,
#   nan,
#   ['political powers'],
#   ['larger asteroids', 'human habitation'],
#   ['various polities', 'ordinary spacecraft'],
#   ['unexpected twists'],
#   ['dead woman', 'continuous presence'],
#   nan,
#   nan,
#   ['alien entity', 'solar system eons', 'solar system', 'real threat'],
#   nan,
#   ['several times', 'same time'],
#   ['better sci fi novels', 'better sci'],
#   ['great story', 'great characters'],
#   nan,
#   ['first season'],
#   ['latest offering'],
#   ['intriguing story line', 'intriguing story'],
#   nan,
#   nan,
#   nan,
#   ['long run'],
#   ['great story'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['good sci fi', 'good sci'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['same time'],
#   nan,
#   nan,
#   ['solar system'],
#   nan,
#   nan,
#   ['good things'],
#   ['long time'],
#   nan,
#   nan,
#   ['last page'],
#   ['second book'],
#   ['epic space opera storytelling', 'epic space opera'],
#   nan,
#   nan,
#   nan,
#   ['real people'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['most cases'],
#   nan,
#   ['hard sci fi', 'great characters', 'hard sci'],
#   ['artistic convention', 'few nods'],
#   nan,
#   ['great sci fi', 'great sci'],
#   ['excellent story'],
#   ['whole thing'],
#   ['more depth', '1st season'],
#   ['2nd book', 'different points'],
#   ['possible spoilers'],
#   ['other parts'],
#   ['unhealthy fascination', 'biggest issue', 'second half'],
#   nan,
#   ['major plot point'],
#   nan,
#   nan,
#   ['other cases', 'first half'],
#   nan,
#   ['second half'],
#   nan,
#   nan,
#   nan,
#   ['great storytelling', 'iteresting setting'],
#   ['next book'],
#   ['interesting read', 'best book'],
#   ['worth areas'],
#   nan,
#   nan,
#   ['nice guy', 'more words'],
#   ['exciting space opera', 'leviathan wakes', 'good characters'],
#   ['other science fiction work', 'deep thoughts'],
#   ['vivid characters', 'good plot', 'coherent world'],
#   ['poor review'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['great job'],
#   ['great book'],
#   nan,
#   nan,
#   nan,
#   ['fashioned cop mystery', 'outer space'],
#   ['fun twists'],
#   ['eclectic variety'],
#   ['second novel'],
#   ['few times'],
#   ['same story', 'short cuts', 'different ways'],
#   nan,
#   ['great find'],
#   ['lazy rendition'],
#   nan,
#   nan,
#   nan,
#   ['first book', 'interesting premise'],
#   ['second one'],
#   ['good book'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['hard facts', 'political situations', 'little bit'],
#   ['alien technology', 'future stories', 'different directions'],
#   nan,
#   nan,
#   ['main characters', 'separate identities'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['hard sci fi story', 'hard sci fi', 'hard sci'],
#   ['big novel'],
#   nan,
#   ['steady pace', 'few pages'],
#   nan,
#   ['solar system', 'believable future'],
#   ['little idea'],
#   nan,
#   nan,
#   ['believable state', 'whole situation'],
#   nan,
#   ['next title'],
#   ['immersive experience'],
#   nan,
#   ['most fans'],
#   nan,
#   ['solid space opera'],
#   ['other shock'],
#   nan,
#   ['best sci fi', 'best sci'],
#   nan,
#   nan,
#   nan,
#   ['nice series'],
#   ['unfathomable aliens', 'unfathomable stuff'],
#   nan,
#   nan,
#   nan,
#   ['great read'],
#   ['great book'],
#   nan,
#   nan,
#   ['good sf series'],
#   nan,
#   ['next installment', 'epic series'],
#   ['syfy show'],
#   nan,
#   ['solar system',
#    'first installment',
#    'great job',
#    'believable world',
#    'more detail'],
#   ['other locations', 'different places', 'human nature'],
#   ['private security agent miller'],
#   ['exciting ways'],
#   ['quick pace'],
#   ['thrilling tale', 'hard time'],
#   nan,
#   nan,
#   ['positive reviewers'],
#   nan,
#   nan,
#   ['great book'],
#   nan,
#   nan,
#   ['3rd season'],
#   ['great book'],
#   nan,
#   ['great writing', 'great story'],
#   ['great job'],
#   nan,
#   ['hard sci fi', 'compelling series', 'hard sci'],
#   nan,
#   ['solar system', 'political upheavals'],
#   nan,
#   ['main characters'],
#   nan,
#   ['good read', 'young adults'],
#   ['few sentances'],
#   nan,
#   nan,
#   nan,
#   ['boyish enthusiasm', 'strong points'],
#   ['aesthetic descriptions'],
#   nan,
#   nan,
#   ['male menopause', 'male characters'],
#   ['confidant female', 'more understanding'],
#   ['idiosyncratic cast system'],
#   ['first name'],
#   ['last names', 'higher rank'],
#   ['white males', 'powerful characters', 'last names'],
#   nan,
#   ['social evolution'],
#   nan,
#   ['good path'],
#   nan,
#   ['long book'],
#   ['fabulous tv show'],
#   nan,
#   nan,
#   nan,
#   ['outer space'],
#   nan,
#   ['good read'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['next book'],
#   nan,
#   ['low setting'],
#   ['excellent space opera',
#    'excellent space',
#    'excellent writing',
#    'memorable characters'],
#   ['entire series'],
#   ['fine job'],
#   ['first season'],
#   nan,
#   nan,
#   nan,
#   ['fast pace story', 'fast pace'],
#   nan,
#   ['major differences'],
#   ['different angle'],
#   ['different scenery', 'different route', 'same destination'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['second read'],
#   ['main twist'],
#   ['first season'],
#   ['authentic decisions', 'seeming characters'],
#   ['real life'],
#   ['realistic politics', 'believable technology'],
#   nan,
#   nan,
#   nan,
#   ['later books', 'first book'],
#   nan,
#   ['hard science fiction', 'hard science'],
#   nan,
#   ['basic science'],
#   ['good novel'],
#   nan,
#   ['many characters'],
#   nan,
#   ['real people'],
#   nan,
#   nan,
#   nan,
#   ['precipitous nose'],
#   ['regressive writing', 'good chance'],
#   nan,
#   nan,
#   ['hard scifi feel', 'hard scifi'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['good story line', 'good story'],
#   nan,
#   nan,
#   ['fascinating experience', 'same time'],
#   nan,
#   nan,
#   ['much time'],
#   nan,
#   nan,
#   ['great story', 'awesome characters'],
#   nan,
#   ['best sci fi story', 'best sci fi', 'best sci'],
#   ['good space fiction novel',
#    'surprising plot twists',
#    'interesting characters'],
#   ['next book'],
#   nan,
#   nan,
#   ['decent ideas'],
#   nan,
#   ['new sub genre'],
#   nan,
#   ['blockbuster science fiction'],
#   ['big budget sci'],
#   ['penultimate example', 'leviathan wakes'],
#   nan,
#   nan,
#   ['leviathan wakes'],
#   ['high expectations', 'interesting hoops'],
#   nan,
#   ['basic story structure'],
#   ['dramatic narrative'],
#   ['talented musician', 'slick way'],
#   ['final product', 'grammatical hiccup'],
#   nan,
#   ['nonsensical story elements'],
#   nan,
#   nan,
#   nan,
#   ['basic science fiction', 'basic science'],
#   nan,
#   ['satisfying way'],
#   nan,
#   ['inconsequential avenues'],
#   nan,
#   nan,
#   ['huge backdrops'],
#   nan,
#   ['solar system', 'middle stage', 'other note'],
#   ['other planets',
#    'solar system',
#    'flung future',
#    'many others',
#    'near future'],
#   ['leviathan wakes', 'solar system', 'outer dichotomy', 'social division'],
#   ['planetary residents', 'gravitational environment', 'lesser class'],
#   ['leviathan wakes', 'dramatic tension'],
#   ['great concept'],
#   nan,
#   ['big mystery'],
#   nan,
#   nan,
#   ['faceted conflict'],
#   ['interesting bits'],
#   nan,
#   nan,
#   nan,
#   ['good book'],
#   ['first book'],
#   ['internal monologs'],
#   nan,
#   nan,
#   nan,
#   ['next book'],
#   ['awesome read'],
#   ['good space opera'],
#   ['sociopolitical milieu', 'new territory', 'certain extent'],
#   ['syfy series'],
#   ['recent road trip', 'audible version'],
#   nan,
#   ['superb plot', 'excellent writing'],
#   nan,
#   ['hard time'],
#   ['intense situations'],
#   nan,
#   ['good start'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['great plot'],
#   nan,
#   nan,
#   nan,
#   ['strong prose', 'good story'],
#   nan,
#   ['ultimate technology stuff'],
#   nan,
#   ['external threat', 'modern framework'],
#   ['many authors'],
#   ['complete novel'],
#   ['more installments'],
#   nan,
#   nan,
#   ['good story', 'second installment', 'good beginning', 'first one'],
#   ['scifi space operas', 'excellent genre'],
#   nan,
#   ['good book'],
#   nan,
#   ['good start'],
#   nan,
#   ['great book'],
#   nan,
#   ['great book'],
#   nan,
#   nan,
#   ['recent pop culture', 'alien virus', 'better job'],
#   ['great book'],
#   ['great book'],
#   ['great book'],
#   ['great series'],
#   nan,
#   ['good read'],
#   nan,
#   ['good start'],
#   nan,
#   nan,
#   ['climatic points', 'vivid justice'],
#   ['epic tale', 'better use', 'human description'],
#   ['rare enjoyment'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['wonderful read'],
#   nan,
#   ['gritty details', 'human themes'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['syfy show', 'same time'],
#   nan,
#   nan,
#   ['great book'],
#   nan,
#   nan,
#   ['new predicaments', 'overall story', 'main characters'],
#   ['genuine space opera', 'grandiose scope'],
#   nan,
#   nan,
#   ['holy hell'],
#   ['nice space opera'],
#   ['most novels'],
#   ['several months'],
#   ['other books'],
#   ['few episodes'],
#   nan,
#   ['second book'],
#   nan,
#   ['later books'],
#   ['first place'],
#   nan,
#   ['hostile environments'],
#   ['tech heads'],
#   ['technological weave'],
#   ['solar system'],
#   nan,
#   nan,
#   nan,
#   ['lower gravity'],
#   nan,
#   nan,
#   ['alien species aspect', 'alien species'],
#   ['fungal infection', 'newtonian physics'],
#   ['good science fiction', 'good science'],
#   nan,
#   nan,
#   ['different voice'],
#   ['other books'],
#   ['refreshing science fiction'],
#   nan,
#   ['great sci fi', 'great sci'],
#   nan,
#   nan,
#   ['blank pages'],
#   ['top notch'],
#   nan,
#   ['great novel'],
#   nan,
#   ['several times'],
#   nan,
#   ['absolute page', 'leviathan wakes'],
#   ['few times'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['latest inferno'],
#   ['whole point'],
#   nan,
#   ['weird outliers'],
#   ['fantastic job'],
#   nan,
#   nan,
#   ['many researchers', 'professional linguist'],
#   nan,
#   ['good books'],
#   ['whole time', 'frank herbert'],
#   ['special effects guys', 'bottom line'],
#   ['right way'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['terrific read'],
#   ['realistic science fiction', 'newtonian physics', 'realistic science'],
#   ['political intrigue', 'human characters'],
#   nan,
#   ['syfy series'],
#   ['more detail'],
#   nan,
#   ['poetic writing'],
#   ['great character development', 'great character', 'amazing offering'],
#   nan,
#   nan,
#   ['rampant greed'],
#   ['next book'],
#   ['other reading materials'],
#   nan,
#   nan,
#   ['great characters', 'dull moment'],
#   ['great science fiction'],
#   ['next book'],
#   ['first time'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['great writing'],
#   nan,
#   nan,
#   ['excellent book'],
#   nan,
#   nan,
#   nan,
#   ['excellent book'],
#   ['paced novel', 'syfy series'],
#   nan,
#   ['favorite reads'],
#   ['detective novel', 'solar earth human civilizations', 'classy piece'],
#   nan,
#   nan,
#   ['believable characters', 'good job', 'difficult situation'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['hard sci fi', 'planetary politics', 'hard sci', 'excellent blend'],
#   ['first couple chapters', 'first couple'],
#   ['next book'],
#   ['excellent science fiction book', 'excellent science fiction'],
#   ['most fiction space operas', 'most fiction'],
#   nan,
#   nan,
#   ['hard sf'],
#   nan,
#   nan,
#   ['great works'],
#   ['scifi channel series', 'scifi channel'],
#   nan,
#   nan,
#   nan,
#   ['reasonable politics', 'big setting'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['other books', 'human physiology'],
#   ['great story'],
#   ['entire expanse trilogy'],
#   ['interesting read', 'surprising twists'],
#   ['classic space opera'],
#   nan,
#   ['next book'],
#   nan,
#   ['solar system', 'high rating', 'future humanity', 'unique perspective'],
#   nan,
#   ['excellent book'],
#   ['real page turner', 'real page'],
#   ['nice payoff', 'great way', 'slow start'],
#   nan,
#   ['dark heroes'],
#   ['own phrase'],
#   ['political nightmare'],
#   ['political tensions', 'masterful job'],
#   nan,
#   nan,
#   ['alien life'],
#   nan,
#   ['solar system', 'near term exploration', 'near term'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['great book'],
#   nan,
#   ['solar system'],
#   ['complex characters'],
#   nan,
#   nan,
#   nan,
#   ['several levels'],
#   nan,
#   nan,
#   ['amazing world building', 'amazing world'],
#   nan,
#   nan,
#   ['suspenseful moments'],
#   ['own voice'],
#   nan,
#   nan,
#   ['great read'],
#   ['great sci fi', 'great sci'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['great book'],
#   ['great story'],
#   ['mass effect'],
#   ['great way'],
#   ['great series', 'great start'],
#   ['leviathan wakes'],
#   nan,
#   nan,
#   nan,
#   ['great series'],
#   nan,
#   ['best writing'],
#   ['early time period'],
#   nan,
#   ['entire series'],
#   ['actual character'],
#   nan,
#   ['first book', 'most people'],
#   ['favorite series'],
#   ...],
#  'rb_rb_nn': [nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ...],
#  'rb_jj_nn': [nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['only realistic politics'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['pretty decent job'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['truly fantastic tale'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['equally cliched characters'],
#   ['not new information'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['rediculously long series'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['more dystopian view'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['incongruously anachronistic stereotype'],
#   nan,
#   nan,
#   nan,
#   ['potentially catastrophic conspiracy'],
#   ['somewhat broken everyman'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['so many moments'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['utterly satisfying read'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['just good character development'],
#   nan,
#   ['much better detail'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['so more heat'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['course several times'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['mostly hard sci fi'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['much more depth'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['definitely worth areas'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['particularly deep thoughts'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['slightly different ways'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['very interesting premise'],
#   nan,
#   ['very good book'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['very believable future'],
#   ['very little idea'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['very immersive experience'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['very nice series'],
#   ['behind unfathomable stuff'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['very compelling series'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['lucidly aesthetic descriptions'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['most powerful characters'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['already long book'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['very good read'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['slightly different angle'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['so many characters'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['as much time'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['very high expectations'],
#   nan,
#   nan,
#   nan,
#   ['supremely talented musician', 'very slick way'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['very satisfying way'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['really good book'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['entirely new territory'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['much better job'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['more human description'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['increasingly hostile environments'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['most good science fiction'],
#   nan,
#   nan,
#   ['completely different voice'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['really great science fiction'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['well paced novel'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['very interesting read'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['really nice payoff'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ...],
#  'rb_vb_nn': [nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['just made everyone'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['intricately built setting'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['really became something'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['extensively explored universes'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['just released book'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['already watched ther series'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['fast paced narrative'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['now rewatch seasons'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['hard boiled detective story'],
#   nan,
#   nan,
#   ['usually choose books'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['often let people'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['also watching season'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['well built world'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['not like mystery novels'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['not give sci'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['still allows time'],
#   ['normally read science fiction'],
#   nan,
#   ['not have time'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['slowly intertwining story arcs'],
#   nan,
#   ['over explain things'],
#   nan,
#   nan,
#   ['well developed characters'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['often give books'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['already watched season'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['currently reading book'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['well built characters'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['faithfully done tv series'],
#   nan,
#   nan,
#   nan,
#   ['rapidly changing milieu'],
#   ['fast paced narrative'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['also made plot changes'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['well developed characters'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['currently reading book'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['well written book'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['possibly have time'],
#   ['not expect anything'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ...],
#  'vb_nn': [nan,
#   nan,
#   ['sci fi'],
#   ['sci fi'],
#   nan,
#   ['sci fi'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['are people'],
#   nan,
#   ['daunting challenges'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['makes sense'],
#   nan,
#   nan,
#   ['like cards ender series'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['get bit'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['like mysteries'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['glowing future'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['captivating writing'],
#   nan,
#   ['made everyone'],
#   nan,
#   ['sci fi'],
#   nan,
#   ['automated recommendation'],
#   nan,
#   nan,
#   ['built setting'],
#   nan,
#   nan,
#   nan,
#   ['asteroid belt'],
#   ['growing resentment', 'perceived exploitation'],
#   nan,
#   nan,
#   nan,
#   ['james sa corey'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['hauling cargo'],
#   nan,
#   nan,
#   ['is series'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['became something'],
#   ['sci fi'],
#   ['sci fi'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['james corey'],
#   nan,
#   nan,
#   ['sci fi'],
#   ['explored universes'],
#   ['crafted universe'],
#   nan,
#   nan,
#   nan,
#   ['learn something'],
#   ['captivating story'],
#   nan,
#   ['watching syfy'],
#   nan,
#   nan,
#   ['read book'],
#   nan,
#   nan,
#   nan,
#   ['thought provoking weeks', 'thought provoking'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['lose interest'],
#   nan,
#   nan,
#   nan,
#   ['takes place'],
#   ['contains action'],
#   ['balancing act'],
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['watching episodes'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['made dialog worthwhile'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['enjoy sci', 'sci fi'],
#   nan,
#   ['lose sleep'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['warring planets', 'is king'],
#   ['is character centric',
#    'writing style',
#    'giving character point',
#    'is character',
#    'got series'],
#   nan,
#   ['is book'],
#   ['released book'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['read book', 'is something'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['shaking amos hand'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['loving devourers'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['shows humanity'],
#   ['watched ther series'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['paced narrative', 'glaring errors'],
#   ['feel momentum', 'created universe'],
#   ['read book'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['rewatch seasons'],
#   nan,
#   nan,
#   nan,
#   ['driven story', 'uses nuts'],
#   nan,
#   nan,
#   ['read scifi'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   nan,
#   ['are people'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   ['thrilling stories', 'give rise'],
#   nan,
#   ['sci fi'],
#   nan,
#   ['boiled detective story', 'boiled detective', 'change humanity'],
#   ['sci fi'],
#   nan,
#   ['choose books'],
#   ['captivating story', 'gain glimpses'],
#   ['incorporating science'],
#   ['james corey'],
#   nan,
#   ['start book'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['asteroid belt'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   nan,
#   nan,
#   ['reading anything'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi'],
#   ['explaining stuff'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   ['sci fi'],
#   nan,
#   ['turning pages'],
#   nan,
#   nan,
#   ['had promise'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   ['find fans'],
#   nan,
#   nan,
#   ['focused story', 'making sense', 'is character'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['thrilling action sequences'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['let people'],
#   nan,
#   nan,
#   nan,
#   ['is part'],
#   ['sci fi'],
#   nan,
#   ['reading science fiction'],
#   nan,
#   nan,
#   ['watching season', 'reading volume'],
#   nan,
#   nan,
#   ['think part', 'takes place'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['liked parts'],
#   ['was miller'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['investigating julie'],
#   ['add tension'],
#   nan,
#   ['lacked depth'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['have time'],
#   nan,
#   nan,
#   nan,
#   ['enjoyed reading'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['running errands'],
#   nan,
#   ['sci fi'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['read leviathan'],
#   nan,
#   ['like science fiction'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['made improvements'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['turning pages', 'built world'],
#   nan,
#   ['proceeding books'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['write characters', 'james corey'],
#   nan,
#   ['like mystery', 'like mystery novels'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   nan,
#   ['brought novelty'],
#   ['loved miller'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi'],
#   ['enjoyed reading'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['enjoy sci', 'sci fi'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi', 'give sci', 'gaining traction'],
#   nan,
#   ['colonized mars', 'asteroid belt', 'following installments'],
#   ['varying degrees'],
#   ['missing girl case', 'missing girl'],
#   nan,
#   ['allows time'],
#   ['read science fiction'],
#   nan,
#   ['have time'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['writing style'],
#   nan,
#   ['sci fi'],
#   nan,
#   ['sci fi'],
#   ['has action'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['setting characters'],
#   nan,
#   nan,
#   nan,
#   ['are transcendent moments'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['reread parts'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['avoid damage'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['are fan'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['doing something'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['is stories'],
#   nan,
#   nan,
#   ['called gravity'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['make mistakes'],
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   nan,
#   nan,
#   ['gets credit'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['read book'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['being science fiction'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['is rock'],
#   nan,
#   nan,
#   nan,
#   ['follows suit'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['intertwining story arcs'],
#   nan,
#   ['explain things'],
#   nan,
#   nan,
#   ['sci fi', 'enjoy sci', 'developed characters'],
#   nan,
#   nan,
#   ['sci fi'],
#   ['asteroid belt'],
#   nan,
#   nan,
#   nan,
#   ['give books'],
#   ['is something'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['added depth'],
#   nan,
#   nan,
#   ['watched season'],
#   nan,
#   nan,
#   nan,
#   ['packed story'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['reading book'],
#   ['sci fi'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['send help'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['built characters'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['is series'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['asteroid belt'],
#   nan,
#   ['likes fiction', 'think anyone'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['hope syfy'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi'],
#   ['known timeline'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['starting reading'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['done tv series'],
#   nan,
#   nan,
#   nan,
#   ['changing milieu',
#    'enthralling experience',
#    'reading mr',
#    'retain humanity'],
#   ['paced narrative'],
#   ['is enrichment'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['left earth'],
#   ['watches world news'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['james corey'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['starting book'],
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['george rr martin'],
#   nan,
#   ['wrote dune'],
#   ['written book'],
#   ['made plot changes'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['had material'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['discussing miller'],
#   nan,
#   nan,
#   nan,
#   ['following books'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['read corey'],
#   nan,
#   ['develops characters'],
#   nan,
#   nan,
#   nan,
#   ['seen tv series'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi', 'is sci'],
#   nan,
#   nan,
#   nan,
#   nan,
#   ['developed characters', 'written art'],
#   nan,
#   ['seeing season'],
#   nan,
#   ['reading book'],
#   ['reading book'],
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['is half'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi'],
#   ['sci fi'],
#   nan,
#   nan,
#   nan,
#   ['humanizes science fiction', 'written book'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['sci fi fans', 'sci fi'],
#   ['sci fi'],
#   nan,
#   ['open war'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['storytelling changes'],
#   nan,
#   nan,
#   nan,
#   ['sci fi'],
#   nan,
#   nan,
#   ['are differences'],
#   nan,
#   ['was everything'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ['give leviathan wakes', 'watched season'],
#   nan,
#   ['have time'],
#   ['expect anything'],
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   nan,
#   ...]}

# %% [markdown]
# #### Add key phrases to DataFrame

# %%
df4 = df3.copy()

for key in keyword_dict2.keys():
    df4[key] = keyword_dict2[key]
df4
# Out:
#                                             review_text  \
# 0     Have read all 6 books after viewing the first ...
# 1     Have read all 6 books after viewing the first ...
# 2     Have read all 6 books after viewing the first ...
# 3     One of the best sci-fi books around.  Good plo...
# 4     One of the best sci-fi books around.  Good plo...
# ...                                                 ...
# 6897  I don't usually write reviews.  This book dese...
# 6898  Was happy to find out there was a book series ...
# 6899  Was happy to find out there was a book series ...
# 6900  Was happy to find out there was a book series ...
# 6901  Was happy to find out there was a book series ...
#
#                                        cleaned_sentence         user_id  \
# 0     have read all 6 books after viewing the first ...   AF7X31XYRC21M
# 1     they were excellent for filling in the backgro...   AF7X31XYRC21M
# 2     can wholeheartedly recommend them to all sci-f...   AF7X31XYRC21M
# 3                  one of the best sci-fi books around.  A1OL3QQXYHQEII
# 4     good plot and believable tech makes this a gre...  A1OL3QQXYHQEII
# ...                                                 ...             ...
# 6897  he would be ejecting rounds unless the gun was...  A1AJDC30B7FKVB
# 6898  was happy to find out there was a book series ...  A3QATDHUASPFUU
# 6899                 read this book in just a few days.  A3QATDHUASPFUU
# 6900  was very impressed with how faithful the tv se...  A3QATDHUASPFUU
# 6901                                    on to book two!  A3QATDHUASPFUU
#
#          book_id  rating                                            summary  \
# 0     0316129089     5.0               Recommend 100% to all sci-fi readers
# 1     0316129089     5.0               Recommend 100% to all sci-fi readers
# 2     0316129089     5.0               Recommend 100% to all sci-fi readers
# 3     0316129089     5.0                                          Good Book
# 4     0316129089     5.0                                          Good Book
# ...          ...     ...                                                ...
# 6897  0316129089     5.0  Great detective story, set in the future and i...
# 6898  0316129089     5.0                                  Excellent Pairing
# 6899  0316129089     5.0                                  Excellent Pairing
# 6900  0316129089     5.0                                  Excellent Pairing
# 6901  0316129089     5.0                                  Excellent Pairing
#
#            date            title                   category  \
# 0    2018-04-19  leviathan wakes  science fiction & fantasy
# 1    2018-04-19  leviathan wakes  science fiction & fantasy
# 2    2018-04-19  leviathan wakes  science fiction & fantasy
# 3    2018-04-18  leviathan wakes  science fiction & fantasy
# 4    2018-04-18  leviathan wakes  science fiction & fantasy
# ...         ...              ...                        ...
# 6897 2018-04-24  leviathan wakes  science fiction & fantasy
# 6898 2018-04-23  leviathan wakes  science fiction & fantasy
# 6899 2018-04-23  leviathan wakes  science fiction & fantasy
# 6900 2018-04-23  leviathan wakes  science fiction & fantasy
# 6901 2018-04-23  leviathan wakes  science fiction & fantasy
#
#                                            jj_nn rb_rb_nn rb_jj_nn rb_vb_nn  \
# 0                                 [first season]      NaN      NaN      NaN
# 1                                            NaN      NaN      NaN      NaN
# 2                                            NaN      NaN      NaN      NaN
# 3     [best sci fi books, best sci fi, best sci]      NaN      NaN      NaN
# 4     [gritty novel, good plot, believable tech]      NaN      NaN      NaN
# ...                                          ...      ...      ...      ...
# 6897                                         NaN      NaN      NaN      NaN
# 6898                                         NaN      NaN      NaN      NaN
# 6899                                  [few days]      NaN      NaN      NaN
# 6900                                         NaN      NaN      NaN      NaN
# 6901                                         NaN      NaN      NaN      NaN
#
#                   vb_nn
# 0                   NaN
# 1                   NaN
# 2              [sci fi]
# 3              [sci fi]
# 4                   NaN
# ...                 ...
# 6897  [ejecting rounds]
# 6898                NaN
# 6899                NaN
# 6900                NaN
# 6901                NaN
#
# [6902 rows x 14 columns]

# %% [markdown]
# #### Re-format list values to string values

# %%
for key in keyword_dict2.keys():
    df4 = df4.explode(key)
df4
# Out:
#                                             review_text  \
# 0     Have read all 6 books after viewing the first ...
# 1     Have read all 6 books after viewing the first ...
# 2     Have read all 6 books after viewing the first ...
# 3     One of the best sci-fi books around.  Good plo...
# 3     One of the best sci-fi books around.  Good plo...
# ...                                                 ...
# 6897  I don't usually write reviews.  This book dese...
# 6898  Was happy to find out there was a book series ...
# 6899  Was happy to find out there was a book series ...
# 6900  Was happy to find out there was a book series ...
# 6901  Was happy to find out there was a book series ...
#
#                                        cleaned_sentence         user_id  \
# 0     have read all 6 books after viewing the first ...   AF7X31XYRC21M
# 1     they were excellent for filling in the backgro...   AF7X31XYRC21M
# 2     can wholeheartedly recommend them to all sci-f...   AF7X31XYRC21M
# 3                  one of the best sci-fi books around.  A1OL3QQXYHQEII
# 3                  one of the best sci-fi books around.  A1OL3QQXYHQEII
# ...                                                 ...             ...
# 6897  he would be ejecting rounds unless the gun was...  A1AJDC30B7FKVB
# 6898  was happy to find out there was a book series ...  A3QATDHUASPFUU
# 6899                 read this book in just a few days.  A3QATDHUASPFUU
# 6900  was very impressed with how faithful the tv se...  A3QATDHUASPFUU
# 6901                                    on to book two!  A3QATDHUASPFUU
#
#          book_id  rating                                            summary  \
# 0     0316129089     5.0               Recommend 100% to all sci-fi readers
# 1     0316129089     5.0               Recommend 100% to all sci-fi readers
# 2     0316129089     5.0               Recommend 100% to all sci-fi readers
# 3     0316129089     5.0                                          Good Book
# 3     0316129089     5.0                                          Good Book
# ...          ...     ...                                                ...
# 6897  0316129089     5.0  Great detective story, set in the future and i...
# 6898  0316129089     5.0                                  Excellent Pairing
# 6899  0316129089     5.0                                  Excellent Pairing
# 6900  0316129089     5.0                                  Excellent Pairing
# 6901  0316129089     5.0                                  Excellent Pairing
#
#            date            title                   category  \
# 0    2018-04-19  leviathan wakes  science fiction & fantasy
# 1    2018-04-19  leviathan wakes  science fiction & fantasy
# 2    2018-04-19  leviathan wakes  science fiction & fantasy
# 3    2018-04-18  leviathan wakes  science fiction & fantasy
# 3    2018-04-18  leviathan wakes  science fiction & fantasy
# ...         ...              ...                        ...
# 6897 2018-04-24  leviathan wakes  science fiction & fantasy
# 6898 2018-04-23  leviathan wakes  science fiction & fantasy
# 6899 2018-04-23  leviathan wakes  science fiction & fantasy
# 6900 2018-04-23  leviathan wakes  science fiction & fantasy
# 6901 2018-04-23  leviathan wakes  science fiction & fantasy
#
#                   jj_nn rb_rb_nn rb_jj_nn rb_vb_nn            vb_nn
# 0          first season      NaN      NaN      NaN              NaN
# 1                   NaN      NaN      NaN      NaN              NaN
# 2                   NaN      NaN      NaN      NaN           sci fi
# 3     best sci fi books      NaN      NaN      NaN           sci fi
# 3           best sci fi      NaN      NaN      NaN           sci fi
# ...                 ...      ...      ...      ...              ...
# 6897                NaN      NaN      NaN      NaN  ejecting rounds
# 6898                NaN      NaN      NaN      NaN              NaN
# 6899           few days      NaN      NaN      NaN              NaN
# 6900                NaN      NaN      NaN      NaN              NaN
# 6901                NaN      NaN      NaN      NaN              NaN
#
# [9727 rows x 14 columns]

# %%
# drop any row/sentence that had no pos pattern values (All NaNs in jj_nn, rb_rb_nn... etc)
df4.dropna(subset=list(keyword_dict2.keys()), how='all', inplace=True)

# %% [markdown]
# #### Separate key phrase descriptive words and noun words
# It is possible to slice the key phrases accurately based off the POS pattern.
# Example: jj_nn will always be in the form of single adjective > noun(s) so the descriptive word will always be index 0 and the noun(s) index 1+.

# %%
for key in keyword_dict2.keys():
    descs = []
    nouns = []
    if key in ['jj_nn','vb_nn']:
        for keyphrase in df4[key]:
            if keyphrase is not np.nan:
                desc = keyphrase.split()[0]
                noun = ' '.join(keyphrase.split()[1:])
                descs.append(desc)
                nouns.append(noun)
            else:
                descs.append(np.nan)
                nouns.append(np.nan)
    elif key in ['rb_rb_nn','rb_jj_nn','rb_vb_nn']:
        for keyphrase in df4[key]:
            if keyphrase is not np.nan:
                desc = ' '.join(keyphrase.split()[:2])
                noun = ' '.join(keyphrase.split()[2:])
                descs.append(desc)
                nouns.append(noun)
            else:
                descs.append(np.nan)
                nouns.append(np.nan)
                
    df4[key + '_desc'] = descs
    df4[key + '_noun'] = nouns
    
df4.head()
# Out:
#                                          review_text  \
# 0  Have read all 6 books after viewing the first ...
# 2  Have read all 6 books after viewing the first ...
# 3  One of the best sci-fi books around.  Good plo...
# 3  One of the best sci-fi books around.  Good plo...
# 3  One of the best sci-fi books around.  Good plo...
#
#                                     cleaned_sentence         user_id  \
# 0  have read all 6 books after viewing the first ...   AF7X31XYRC21M
# 2  can wholeheartedly recommend them to all sci-f...   AF7X31XYRC21M
# 3               one of the best sci-fi books around.  A1OL3QQXYHQEII
# 3               one of the best sci-fi books around.  A1OL3QQXYHQEII
# 3               one of the best sci-fi books around.  A1OL3QQXYHQEII
#
#       book_id  rating                               summary       date  \
# 0  0316129089     5.0  Recommend 100% to all sci-fi readers 2018-04-19
# 2  0316129089     5.0  Recommend 100% to all sci-fi readers 2018-04-19
# 3  0316129089     5.0                             Good Book 2018-04-18
# 3  0316129089     5.0                             Good Book 2018-04-18
# 3  0316129089     5.0                             Good Book 2018-04-18
#
#              title                   category              jj_nn rb_rb_nn  \
# 0  leviathan wakes  science fiction & fantasy       first season      NaN
# 2  leviathan wakes  science fiction & fantasy                NaN      NaN
# 3  leviathan wakes  science fiction & fantasy  best sci fi books      NaN
# 3  leviathan wakes  science fiction & fantasy        best sci fi      NaN
# 3  leviathan wakes  science fiction & fantasy           best sci      NaN
#
#   rb_jj_nn rb_vb_nn   vb_nn jj_nn_desc    jj_nn_noun rb_rb_nn_desc  \
# 0      NaN      NaN     NaN      first        season           NaN
# 2      NaN      NaN  sci fi        NaN           NaN           NaN
# 3      NaN      NaN  sci fi       best  sci fi books           NaN
# 3      NaN      NaN  sci fi       best        sci fi           NaN
# 3      NaN      NaN  sci fi       best           sci           NaN
#
#   rb_rb_nn_noun rb_jj_nn_desc rb_jj_nn_noun rb_vb_nn_desc rb_vb_nn_noun  \
# 0           NaN           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
# 3           NaN           NaN           NaN           NaN           NaN
#
#   vb_nn_desc vb_nn_noun
# 0        NaN        NaN
# 2        sci         fi
# 3        sci         fi
# 3        sci         fi
# 3        sci         fi

# %%
# static/non-keyphrase/non-pos pattern columns
id_vars = [
    'review_text',
    'cleaned_sentence',
    'user_id',
    'book_id',
    'rating',
    'summary',
    'date',
    'title',
    'category',
]

# iterate through keyphrase/pos_pattern columns and consolidate into keyphrase/desc/noun columns in new dataframe
dfs = []
for key in keyword_dict2.keys():
    desc_col = key + '_desc'
    noun_col = key + '_noun'
    df_ = (
        df4[id_vars + [key, desc_col, noun_col]]
        .rename(columns={key:'keyphrase', desc_col:'desc', noun_col:'noun'})
    )
    dfs.append(df_)
    
df5 = (
    pd.concat(dfs, ignore_index=True)
    .dropna(subset=['desc','noun'])
    .drop_duplicates(subset=['cleaned_sentence','desc','noun'])
    .reset_index(drop=True)
)
df5
# Out:
#                                             review_text  \
# 0     Have read all 6 books after viewing the first ...
# 1     One of the best sci-fi books around.  Good plo...
# 2     One of the best sci-fi books around.  Good plo...
# 3     One of the best sci-fi books around.  Good plo...
# 4     One of the best sci-fi books around.  Good plo...
# ...                                                 ...
# 8037  It's so good you don't realize time is passing...
# 8038  I don't usually write reviews.  This book dese...
# 8039  I don't usually write reviews.  This book dese...
# 8040  I don't usually write reviews.  This book dese...
# 8041  I don't usually write reviews.  This book dese...
#
#                                        cleaned_sentence         user_id  \
# 0     have read all 6 books after viewing the first ...   AF7X31XYRC21M
# 1                  one of the best sci-fi books around.  A1OL3QQXYHQEII
# 2                  one of the best sci-fi books around.  A1OL3QQXYHQEII
# 3                  one of the best sci-fi books around.  A1OL3QQXYHQEII
# 4     good plot and believable tech makes this a gre...  A1OL3QQXYHQEII
# ...                                                 ...             ...
# 8037  it is so good you do not realize time is passi...  A36GNTONCY1F6M
# 8038                    i do not usually write reviews.  A1AJDC30B7FKVB
# 8039  this book deserved the effort to at least put ...  A1AJDC30B7FKVB
# 8040  i am a police detective and i felt miller's ch...  A1AJDC30B7FKVB
# 8041  he would be ejecting rounds unless the gun was...  A1AJDC30B7FKVB
#
#          book_id  rating                                            summary  \
# 0     0316129089     5.0               Recommend 100% to all sci-fi readers
# 1     0316129089     5.0                                          Good Book
# 2     0316129089     5.0                                          Good Book
# 3     0316129089     5.0                                          Good Book
# 4     0316129089     5.0                                          Good Book
# ...          ...     ...                                                ...
# 8037  0316129089     5.0                                         Great book
# 8038  0316129089     5.0  Great detective story, set in the future and i...
# 8039  0316129089     5.0  Great detective story, set in the future and i...
# 8040  0316129089     5.0  Great detective story, set in the future and i...
# 8041  0316129089     5.0  Great detective story, set in the future and i...
#
#            date            title                   category  \
# 0    2018-04-19  leviathan wakes  science fiction & fantasy
# 1    2018-04-18  leviathan wakes  science fiction & fantasy
# 2    2018-04-18  leviathan wakes  science fiction & fantasy
# 3    2018-04-18  leviathan wakes  science fiction & fantasy
# 4    2018-04-18  leviathan wakes  science fiction & fantasy
# ...         ...              ...                        ...
# 8037 2018-04-27  leviathan wakes  science fiction & fantasy
# 8038 2018-04-24  leviathan wakes  science fiction & fantasy
# 8039 2018-04-24  leviathan wakes  science fiction & fantasy
# 8040 2018-04-24  leviathan wakes  science fiction & fantasy
# 8041 2018-04-24  leviathan wakes  science fiction & fantasy
#
#               keyphrase      desc          noun
# 0          first season     first        season
# 1     best sci fi books      best  sci fi books
# 2           best sci fi      best        sci fi
# 3              best sci      best           sci
# 4          gritty novel    gritty         novel
# ...                 ...       ...           ...
# 8037       realize time   realize          time
# 8038      write reviews     write       reviews
# 8039      put something       put     something
# 8040        felt miller      felt        miller
# 8041    ejecting rounds  ejecting        rounds
#
# [8042 rows x 12 columns]

# %% [markdown]
# # Neural topic modeling
# + Seed word guided BERTopic model
# + Stopwords were not removed prior to this because they contribute to the context for transformer-based embedding models.
#   + CountVectorizer removes stopwords for you
# + The diversity hyperparameter diversifies the words used for each topic reducing overlap
# + Pre-trained SentenceTransformer model 'all-MiniLM-L6-v2' has history of good out-of-the-box performance
#   + Helps when training your own model is infeasible
# + N-grams are automatically considered based off the specified range

# %%
docs_to_use = df5.cleaned_sentence.unique().tolist() # docs or raw_docs

sentence_model = SentenceTransformer("all-MiniLM-L6-v2")
embeddings = sentence_model.encode(docs_to_use, show_progress_bar=False)

vectorizer_model = CountVectorizer(stop_words="english") # removing stop words

diversity = 0.7 # diversify topic representation

topic_model = BERTopic(
    embedding_model=sentence_model,
    vectorizer_model=vectorizer_model,
    diversity=diversity, # diversify topic representation
    n_gram_range=(1,3), # n_grams from N to N
    nr_topics='auto', # automatically select number of topics
    seed_topic_list=seed_keywords # guided topic modeling
)
topics, probs = topic_model.fit_transform(docs_to_use, embeddings)

# %%
# consolidating in dataframe
topic_df = pd.DataFrame({'cleaned_sentence':docs_to_use, 'topic_n':topic_model.topics_})
topic_df['topic'] = topic_df.topic_n.map(topic_model.topic_labels_)

topic_df['topic_freq'] = topic_df.topic_n.apply(lambda x: topic_model.get_topic_freq(x))
topic_df = topic_df.loc[topic_df.topic_n != -1] # -1's are outliers from topic model and should be ignored
topic_df
# Out:
#                                        cleaned_sentence  topic_n  \
# 0     have read all 6 books after viewing the first ...        6
# 1                  one of the best sci-fi books around.        0
# 4     like the parallels of a future society with ou...        5
# 5     it is not often that a television show gets me...        6
# 11    awesome book and you will be ready to keep rea...        0
# ...                                                 ...      ...
# 4094  if you are wanting something more meaty, thoug...        0
# 4097  the reviews are at least partly true: it is a ...        1
# 4099  the book also suffers from being badly edited ...        0
# 4101  this book deserved the effort to at least put ...        0
# 4102  he would be ejecting rounds unless the gun was...       22
#
#                                topic  topic_freq
# 0       6_expanse_syfy_channel_based          79
# 1       0_great_sci_characters_books        1528
# 4     5_future_universe_near_authors          83
# 5       6_expanse_syfy_channel_based          79
# 11      0_great_sci_characters_books        1528
# ...                              ...         ...
# 4094    0_great_sci_characters_books        1528
# 4097       1_operas_noir_solar_wakes         199
# 4099    0_great_sci_characters_books        1528
# 4101    0_great_sci_characters_books        1528
# 4102   22_ships_oft_phalanx_sneaking          10
#
# [2657 rows x 4 columns]

# %% [markdown]
# # Sentiment analysis

# %% [markdown]
# #### Load pre-trained sentiment model

# %%
# https://huggingface.co/siebert/sentiment-roberta-large-english?text=I+like+you.+I+love+you
model = 'siebert/sentiment-roberta-large-english'
sentiment_pipeline = pipeline("sentiment-analysis", model=model)

# %% [markdown]
# ### Aspect-based sentiment analysis
# + Produces sentiments of aspects that are buried within sentences
#   + Most sentiment analyses produce a sentiment for the entire review
# + Allows you to determine sentiment about specific nouns within sentences
#   + In this case it is sentiment of elements of writing and books

# %%
# %%time
docs = df5.keyphrase.tolist()
# sentiment model
sents = sentiment_pipeline(docs)

# get sentiment label (POSITIVE/NEGATIVE) and sentiment score for each keyphrase
labels = []
scores = []
for sent_dict in sents:
    labels.append(sent_dict['label'])
    scores.append(sent_dict['score'])
    
df5['sent_label'] = labels
df5['sent_score'] = scores

# changing negative sentiments to negative values in order to aggregate with positive sentiments
df5.sent_score[df5.sent_label == 'NEGATIVE'] *= -1

# lemmatizing nouns
lemma_dict = {}
unique_nouns = df5.noun.unique().tolist()
for noun in unique_nouns:
    doc = nlp(noun)
    for token in doc:
        lemma = token.lemma_
        lemma_dict[noun] = lemma
df5['aspect'] = df5.noun.map(lemma_dict)

df5.head()
# Out:
# Wall time: 13min 7s
#                                          review_text  \
# 0  Have read all 6 books after viewing the first ...
# 1  One of the best sci-fi books around.  Good plo...
# 2  One of the best sci-fi books around.  Good plo...
# 3  One of the best sci-fi books around.  Good plo...
# 4  One of the best sci-fi books around.  Good plo...
#
#                                     cleaned_sentence         user_id  \
# 0  have read all 6 books after viewing the first ...   AF7X31XYRC21M
# 1               one of the best sci-fi books around.  A1OL3QQXYHQEII
# 2               one of the best sci-fi books around.  A1OL3QQXYHQEII
# 3               one of the best sci-fi books around.  A1OL3QQXYHQEII
# 4  good plot and believable tech makes this a gre...  A1OL3QQXYHQEII
#
#       book_id  rating                               summary       date  \
# 0  0316129089     5.0  Recommend 100% to all sci-fi readers 2018-04-19
# 1  0316129089     5.0                             Good Book 2018-04-18
# 2  0316129089     5.0                             Good Book 2018-04-18
# 3  0316129089     5.0                             Good Book 2018-04-18
# 4  0316129089     5.0                             Good Book 2018-04-18
#
#              title                   category          keyphrase    desc  \
# 0  leviathan wakes  science fiction & fantasy       first season   first
# 1  leviathan wakes  science fiction & fantasy  best sci fi books    best
# 2  leviathan wakes  science fiction & fantasy        best sci fi    best
# 3  leviathan wakes  science fiction & fantasy           best sci    best
# 4  leviathan wakes  science fiction & fantasy       gritty novel  gritty
#
#            noun sent_label  sent_score  aspect
# 0        season   POSITIVE    0.997024  season
# 1  sci fi books   POSITIVE    0.997981    book
# 2        sci fi   POSITIVE    0.997966      fi
# 3           sci   POSITIVE    0.997982     sci
# 4         novel   POSITIVE    0.985310   novel

# %% [markdown]
# #### Reduce to seed keyword aspects only and aggregate sentiments for each aspect

# %%
seed_keyword_df = df5.loc[df5.aspect.isin(seed_keywords)]

seed_keyword_sents = (
    seed_keyword_df
    .groupby(['aspect'], as_index=False)
    .agg(
        sent_score_sum=('sent_score','sum'),
        sent_score_mean=('sent_score','mean'),
        keyphrase_count=('aspect','count')
    )
    .sort_values(by='keyphrase_count', ascending=False)
    .assign(
        pct_total = lambda df_: df_.keyphrase_count / df_.keyphrase_count.sum(),
        running_pct_total = lambda df_: df_.pct_total.cumsum()
    )
)
seed_keyword_sents
# Out:
#          aspect  sent_score_sum  sent_score_mean  keyphrase_count  pct_total  \
# 2     character      257.788031         0.687435              375   0.572519
# 10         plot       50.891549         0.524655               97   0.148092
# 0        action       22.968439         0.620769               37   0.056489
# 1        author       25.727520         0.803985               32   0.048855
# 13        style       26.667558         0.919571               29   0.044275
# 14        theme        9.905203         0.550289               18   0.027481
# 4      conflict       -4.096526        -0.292609               14   0.021374
# 6      dialogue        6.674342         0.606758               11   0.016794
# 9        pacing        9.987781         0.998778               10   0.015267
# 5   description       -0.760896        -0.084544                9   0.013740
# 7    exposition       -1.987597        -0.496899                4   0.006107
# 8    motivation        1.989698         0.497425                4   0.006107
# 11   resolution       -0.001937        -0.000484                4   0.006107
# 12      setting        3.993336         0.998334                4   0.006107
# 15         tone        1.987616         0.496904                4   0.006107
# 3        climax        2.996105         0.998702                3   0.004580
#
#     running_pct_total
# 2            0.572519
# 10           0.720611
# 0            0.777099
# 1            0.825954
# 13           0.870229
# 14           0.897710
# 4            0.919084
# 6            0.935878
# 9            0.951145
# 5            0.964885
# 7            0.970992
# 8            0.977099
# 11           0.983206
# 12           0.989313
# 15           0.995420
# 3            1.000000

# %% [markdown]
# #### Plot aspect-based sentiments
# + Color indicates mean sentiment (-1/red most negative, 1/blue most positive)
# + X-axis represents the number of aspect occurences in the user reviews of the specified book
# + This is a simple method to determine how important a given aspect sentiment is (three people may like the climax but it is only three opinions)

# %%
cmap = mpl.cm.RdBu

plt.figure(figsize=(15,15))
norm = plt.Normalize(-1, 1)

# plot
plt.barh(
    seed_keyword_sents.aspect,
    seed_keyword_sents.keyphrase_count,
    color=cmap(norm(seed_keyword_sents.sent_score_mean.values)),
    alpha=0.7
)

plt.xlabel('Aspect Count')
plt.gca().invert_yaxis()
plt.title('Aspect Sentiments')

# colorbar
sm = ScalarMappable(
    cmap=cmap,
    norm=plt.Normalize(-1, 1)
)
sm.set_array([])
cbar = plt.colorbar(sm)
cbar.set_label('<<< Positive Sentiment | Negative Sentiment >>>', rotation=270,labelpad=25)

plt.show()

# %% [markdown]
# ## Neural topic modeling based sentiment analysis
# + Provides meta and content focused sentiments
#   + Can possibly have some topics similar to the previously shown aspects, but also produces content-focused topics
#   + For example:
#     + The topic 'fi_recommended_asimov_readable' gives the impression the book is comparable to Isaac Asimov novels
#     + While the topic 'corey_ty_pen_sa' won't make sense unless you know they are talking about the co-authors combined pen name (James S.A. Corey)

# %%
# %%time
docs = topic_df.cleaned_sentence.tolist()
# sentiment model
sents = sentiment_pipeline(docs)

# get sentiment label (POSITIVE/NEGATIVE) and sentiment score for each keyphrase
labels = []
scores = []
for sent_dict in sents:
    labels.append(sent_dict['label'])
    scores.append(sent_dict['score'])
    
topic_df['sent_label'] = labels
topic_df['sent_score'] = scores

# reversing negative sentiments to negative values in order to aggregate with positive sentiments
topic_df.sent_score[topic_df.sent_label == 'NEGATIVE'] *= -1
# remove prefix topic numbers from topics
topic_df['topic'] = topic_df.topic.apply(lambda x: x.lstrip('0123456789._ '))
topic_df.head()
# Out:
# Wall time: 5min 46s
#                                      cleaned_sentence  topic_n  \
# 0   have read all 6 books after viewing the first ...        6
# 1                one of the best sci-fi books around.        0
# 4   like the parallels of a future society with ou...        5
# 5   it is not often that a television show gets me...        6
# 11  awesome book and you will be ready to keep rea...        0
#
#                            topic  topic_freq sent_label  sent_score
# 0     expanse_syfy_channel_based          79   POSITIVE    0.998440
# 1     great_sci_characters_books        1528   POSITIVE    0.998820
# 4   future_universe_near_authors          83   POSITIVE    0.997811
# 5     expanse_syfy_channel_based          79   POSITIVE    0.998721
# 11    great_sci_characters_books        1528   POSITIVE    0.998861

# %% [markdown]
# #### Aggregate sentiments for each topic

# %%
topic_sents = (
    topic_df
    .groupby(['topic'], as_index=False)
    .agg(
        sent_score_sum=('sent_score','sum'),
        sent_score_mean=('sent_score','mean'),
        topic_count=('topic','count')
    )
    .sort_values(by='topic_count', ascending=False)
    .assign(
        pct_total = lambda df_: df_.topic_count / df_.topic_count.sum(),
        running_pct_total = lambda df_: df_.pct_total.cumsum()
    )
)
topic_sents
# Out:
#                                     topic  sent_score_sum  sent_score_mean  \
# 9              great_sci_characters_books     1032.682074         0.675839
# 14                operas_noir_solar_wakes      143.561727         0.721416
# 10     holden_miller_detective_idealistic       43.201660         0.363039
# 12            leviathan_fiction_corey_new       58.069551         0.547826
# 2                       corey_pen_ty_does       59.926389         0.696818
# 7            future_universe_near_authors       50.843551         0.612573
# 5              expanse_syfy_channel_based       68.845975         0.871468
# 17           plot_unexpected_like_complex       29.928634         0.404441
# 0      belters_colonized_asteroids_humans       19.019275         0.311791
# 21            solar_set_humans_overlooked       37.840311         0.727698
# 19     setting_factions_degrees_prejudice       27.407261         0.583133
# 6                  fiction_read_best_year       37.119203         0.824871
# 11           kindle_bought_daily_actually        3.971929         0.180542
# 16          physics_spin_artificial_floor        6.983916         0.332567
# 13  miller_especially_unreliable_politick       12.969368         0.682598
# 18     prologue_unanswered_guessing_keeps       -1.010297        -0.053174
# 22     zombies_corporation_disdain_joking       -9.962461        -0.553470
# 3   dialog_internal_monologues_characters        9.016566         0.530386
# 15            path_dragon_abraham_include        0.044067         0.002754
# 1         caliban_war_specifics_engrossed        3.998460         0.333205
# 8                    genre_pub_gap_canyon        9.980741         0.831728
# 4    discovery_story_superficial_sniffles        0.016177         0.001348
# 20             ships_oft_phalanx_sneaking        3.923748         0.392375
#
#     topic_count  pct_total  running_pct_total
# 9          1528   0.575085           0.575085
# 14          199   0.074896           0.649981
# 10          119   0.044787           0.694769
# 12          106   0.039895           0.734663
# 2            86   0.032367           0.767030
# 7            83   0.031238           0.798269
# 5            79   0.029733           0.828002
# 17           74   0.027851           0.855852
# 0            61   0.022958           0.878811
# 21           52   0.019571           0.898382
# 19           47   0.017689           0.916071
# 6            45   0.016936           0.933007
# 11           22   0.008280           0.941287
# 16           21   0.007904           0.949191
# 13           19   0.007151           0.956342
# 18           19   0.007151           0.963493
# 22           18   0.006775           0.970267
# 3            17   0.006398           0.976665
# 15           16   0.006022           0.982687
# 1            12   0.004516           0.987204
# 8            12   0.004516           0.991720
# 4            12   0.004516           0.996236
# 20           10   0.003764           1.000000

# %% [markdown]
# #### Plot neural topic modeling based sentiments
# + Color indicates mean sentiment (-1/red most negative, 1/blue most positive)
# + X-axis represents the number of topic occurences

# %%
cmap = mpl.cm.RdBu

plt.figure(figsize=(15,15))
norm = plt.Normalize(-1, 1)

# plot
plt.barh(
    topic_sents.topic,
    topic_sents.topic_count,
    color=cmap(norm(topic_sents.sent_score_mean.values)),
    alpha=0.7
)
plt.xlabel('Topic Count')
plt.gca().invert_yaxis()
plt.title('Modeled Topic Sentiments')

# colorbar
sm = ScalarMappable(
    cmap=cmap,
    norm=plt.Normalize(-1, 1)
)
sm.set_array([])
cbar = plt.colorbar(sm)
cbar.set_label('<<< Positive Sentiment | Negative Sentiment >>>', rotation=270,labelpad=25)

plt.show()
